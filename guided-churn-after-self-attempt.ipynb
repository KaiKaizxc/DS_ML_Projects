# %%
import pandas as pd 

import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

sns.set_style("darkgrid")

# %%
df = pd.read_csv("../input/churn-modelling/Churn_Modelling.csv")
df.sample(5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 8599       8600    15708713       Hill          633    France    Male   35
# 4345       4346    15584536     Barber          720   Germany    Male   46
# 9948       9949    15735078  Onwughara          724   Germany  Female   53
# 5387       5388    15624072    Kiernan          669     Spain    Male   22
# 3127       3128    15721007   Charlton          776   Germany    Male   33
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 8599       3       0.00              2          1               1
# 4345       3   97042.60              1          1               1
# 9948       1  139687.66              2          1               1
# 5387      10       0.00              2          1               0
# 3127       8  115130.34              1          0               0
#
#       EstimatedSalary  Exited
# 8599         36249.76       0
# 4345        133516.51       1
# 9948         12913.92       0
# 5387        176163.74       0
# 3127        129525.50       1

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# eda 

df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
sns.countplot(data = df, x = "Exited")
plt.show()

# %% [markdown]
# Looks like 20% of the customers have churned and 80% haven't

# %%
# visualizing categorical variables 

fig, ax = plt.subplots(3, 2, figsize = (18, 15))

sns.countplot('Geography', hue = 'Exited', data = df, ax = ax[0][0])
sns.countplot('Gender', hue = 'Exited', data = df, ax = ax[0][1])
sns.countplot('Tenure', hue = 'Exited', data = df, ax = ax[1][0])
sns.countplot('NumOfProducts', hue = 'Exited', data = df, ax = ax[1][1])
sns.countplot('HasCrCard', hue = 'Exited', data = df, ax = ax[2][0])
sns.countplot('IsActiveMember', hue = 'Exited', data = df, ax = ax[2][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# From the above plots we can conclude that:
#
# <li>Majority of the customers are from france but more customers have churned from Germany</li>
# <li>The proportion of female customers churning is also greater than that of male customers </li>
# <li>The majority of the people who churned are not an active member</li>
# <li>Many people have products from 0 ~ 1, only a handful have more than 1</li>

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %%
# heatmap 

plt.figure(figsize = (20, 12))

corr = df.corr()

sns.heatmap(corr, cmap = "RdBu", linewidths = 1, annot = True, fmt = ".2f")
plt.show()

# %% [markdown]
# We can say that there is no multicolinearity present in data

# %%
# dropping useless columns 

df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# creating features and label 

from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis = 1)
y = to_categorical(df.Exited)

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# 2022-11-18 13:28:30.012386: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-11-18 13:28:30.212860: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 188/188 [==============================] - 2s 4ms/step - loss: 0.6226 - accuracy: 0.6643 - val_loss: 0.5766 - val_accuracy: 0.7933
# Epoch 2/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4831 - accuracy: 0.7990 - val_loss: 0.4606 - val_accuracy: 0.7933
# Epoch 3/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3998 - accuracy: 0.8425 - val_loss: 0.3794 - val_accuracy: 0.8447
# Epoch 4/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3903 - accuracy: 0.8433 - val_loss: 0.3597 - val_accuracy: 0.8527
# Epoch 5/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3824 - accuracy: 0.8460 - val_loss: 0.3630 - val_accuracy: 0.8560
# Epoch 6/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.8445 - val_loss: 0.3542 - val_accuracy: 0.8600
# Epoch 7/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3729 - accuracy: 0.8498 - val_loss: 0.3539 - val_accuracy: 0.8560
# Epoch 8/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3762 - accuracy: 0.8478 - val_loss: 0.3590 - val_accuracy: 0.8480
# Epoch 9/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3721 - accuracy: 0.8458 - val_loss: 0.3537 - val_accuracy: 0.8600
# Epoch 10/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3738 - accuracy: 0.8470 - val_loss: 0.3509 - val_accuracy: 0.8573
# Epoch 11/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3702 - accuracy: 0.8458 - val_loss: 0.3507 - val_accuracy: 0.8607
# Epoch 12/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3675 - accuracy: 0.8465 - val_loss: 0.3547 - val_accuracy: 0.8553
# Epoch 13/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3776 - accuracy: 0.8430 - val_loss: 0.3568 - val_accuracy: 0.8527
# Epoch 14/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3675 - accuracy: 0.8485 - val_loss: 0.3487 - val_accuracy: 0.8547
# Epoch 15/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3741 - accuracy: 0.8482 - val_loss: 0.3499 - val_accuracy: 0.8627
# Epoch 16/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3686 - accuracy: 0.8465 - val_loss: 0.3485 - val_accuracy: 0.8573
# Epoch 17/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3706 - accuracy: 0.8468 - val_loss: 0.3486 - val_accuracy: 0.8620
# Epoch 18/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3731 - accuracy: 0.8488 - val_loss: 0.3564 - val_accuracy: 0.8520
# Epoch 19/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3678 - accuracy: 0.8462 - val_loss: 0.3558 - val_accuracy: 0.8540
# Epoch 20/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.8483 - val_loss: 0.3528 - val_accuracy: 0.8587
# Epoch 21/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3671 - accuracy: 0.8520 - val_loss: 0.3476 - val_accuracy: 0.8673
# Epoch 22/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3679 - accuracy: 0.8515 - val_loss: 0.3492 - val_accuracy: 0.8627
# Epoch 23/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3676 - accuracy: 0.8505 - val_loss: 0.3512 - val_accuracy: 0.8560
# Epoch 24/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8528 - val_loss: 0.3573 - val_accuracy: 0.8467
# Epoch 25/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3691 - accuracy: 0.8495 - val_loss: 0.3482 - val_accuracy: 0.8593
# Epoch 26/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3745 - accuracy: 0.8507 - val_loss: 0.3492 - val_accuracy: 0.8607
# Epoch 27/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3779 - accuracy: 0.8465 - val_loss: 0.3485 - val_accuracy: 0.8587
# Epoch 28/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8503 - val_loss: 0.3454 - val_accuracy: 0.8587
# Epoch 29/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8483 - val_loss: 0.3584 - val_accuracy: 0.8580
# Epoch 30/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8530 - val_loss: 0.3491 - val_accuracy: 0.8587
# Epoch 31/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8512 - val_loss: 0.3455 - val_accuracy: 0.8580
# Epoch 32/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3690 - accuracy: 0.8485 - val_loss: 0.3558 - val_accuracy: 0.8600
# Epoch 33/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8522 - val_loss: 0.3525 - val_accuracy: 0.8587
# Epoch 34/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3696 - accuracy: 0.8518 - val_loss: 0.3529 - val_accuracy: 0.8573
# Epoch 35/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3689 - accuracy: 0.8495 - val_loss: 0.3485 - val_accuracy: 0.8553
# Epoch 36/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8482 - val_loss: 0.3528 - val_accuracy: 0.8493
# Epoch 37/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8540 - val_loss: 0.3509 - val_accuracy: 0.8507
# Epoch 38/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3719 - accuracy: 0.8515 - val_loss: 0.3537 - val_accuracy: 0.8567
# Epoch 39/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8458 - val_loss: 0.3514 - val_accuracy: 0.8540
# Epoch 40/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3656 - accuracy: 0.8487 - val_loss: 0.3576 - val_accuracy: 0.8507
# Epoch 41/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8505 - val_loss: 0.3540 - val_accuracy: 0.8520
# Epoch 42/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3605 - accuracy: 0.8512 - val_loss: 0.3548 - val_accuracy: 0.8500
# Epoch 43/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3647 - accuracy: 0.8525 - val_loss: 0.3495 - val_accuracy: 0.8593
# Epoch 44/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3659 - accuracy: 0.8533 - val_loss: 0.3582 - val_accuracy: 0.8573
# Epoch 45/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8553 - val_loss: 0.3504 - val_accuracy: 0.8587
# Epoch 46/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3639 - accuracy: 0.8518 - val_loss: 0.3542 - val_accuracy: 0.8600
# Epoch 47/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.8542 - val_loss: 0.3602 - val_accuracy: 0.8513
# Epoch 48/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3635 - accuracy: 0.8527 - val_loss: 0.3513 - val_accuracy: 0.8567
# Epoch 49/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.8517 - val_loss: 0.3591 - val_accuracy: 0.8627
# Epoch 50/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8520 - val_loss: 0.3546 - val_accuracy: 0.8593
# Epoch 51/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3636 - accuracy: 0.8530 - val_loss: 0.3522 - val_accuracy: 0.8600
# Epoch 52/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3643 - accuracy: 0.8532 - val_loss: 0.3566 - val_accuracy: 0.8567
# Epoch 53/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3634 - accuracy: 0.8545 - val_loss: 0.3569 - val_accuracy: 0.8607
# Epoch 54/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3667 - accuracy: 0.8528 - val_loss: 0.3536 - val_accuracy: 0.8487
# Epoch 55/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3636 - accuracy: 0.8503 - val_loss: 0.3507 - val_accuracy: 0.8507
# Epoch 56/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3664 - accuracy: 0.8483 - val_loss: 0.3511 - val_accuracy: 0.8540
# Epoch 57/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3634 - accuracy: 0.8490 - val_loss: 0.3527 - val_accuracy: 0.8593
# Epoch 58/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3663 - accuracy: 0.8472 - val_loss: 0.3547 - val_accuracy: 0.8520
# Epoch 59/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3643 - accuracy: 0.8498 - val_loss: 0.3521 - val_accuracy: 0.8613
# Epoch 60/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3657 - accuracy: 0.8510 - val_loss: 0.3568 - val_accuracy: 0.8587
# Epoch 61/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3604 - accuracy: 0.8537 - val_loss: 0.3495 - val_accuracy: 0.8593
# Epoch 62/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3644 - accuracy: 0.8530 - val_loss: 0.3653 - val_accuracy: 0.8507
# Epoch 63/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3640 - accuracy: 0.8505 - val_loss: 0.3570 - val_accuracy: 0.8593
# Epoch 64/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3607 - accuracy: 0.8563 - val_loss: 0.3555 - val_accuracy: 0.8553
# Epoch 65/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3696 - accuracy: 0.8488 - val_loss: 0.3632 - val_accuracy: 0.8540
# Epoch 66/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3629 - accuracy: 0.8495 - val_loss: 0.3531 - val_accuracy: 0.8613
# Epoch 67/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8533 - val_loss: 0.3541 - val_accuracy: 0.8560
# Epoch 68/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8553 - val_loss: 0.3506 - val_accuracy: 0.8567
# Epoch 69/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3624 - accuracy: 0.8553 - val_loss: 0.3518 - val_accuracy: 0.8567
# Epoch 70/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3715 - accuracy: 0.8457 - val_loss: 0.3612 - val_accuracy: 0.8567
# Epoch 71/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3660 - accuracy: 0.8520 - val_loss: 0.3575 - val_accuracy: 0.8533
# Epoch 72/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3591 - accuracy: 0.8535 - val_loss: 0.3634 - val_accuracy: 0.8547
# Epoch 73/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.8557 - val_loss: 0.3528 - val_accuracy: 0.8613
# Epoch 74/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.8533 - val_loss: 0.3550 - val_accuracy: 0.8587
# Epoch 75/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8455 - val_loss: 0.3616 - val_accuracy: 0.8567
# Epoch 76/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8503 - val_loss: 0.3590 - val_accuracy: 0.8600
# Epoch 77/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8520 - val_loss: 0.3496 - val_accuracy: 0.8627
# Epoch 78/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.8550 - val_loss: 0.3532 - val_accuracy: 0.8593
# Epoch 79/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8488 - val_loss: 0.3572 - val_accuracy: 0.8600
# Epoch 80/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3600 - accuracy: 0.8517 - val_loss: 0.3469 - val_accuracy: 0.8593
# Epoch 81/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3657 - accuracy: 0.8513 - val_loss: 0.3546 - val_accuracy: 0.8547
# Epoch 82/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3627 - accuracy: 0.8527 - val_loss: 0.3515 - val_accuracy: 0.8520
# Epoch 83/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3609 - accuracy: 0.8515 - val_loss: 0.3510 - val_accuracy: 0.8620
# Epoch 84/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3686 - accuracy: 0.8462 - val_loss: 0.3588 - val_accuracy: 0.8513
# Epoch 85/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3619 - accuracy: 0.8517 - val_loss: 0.3541 - val_accuracy: 0.8587
# Epoch 86/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3663 - accuracy: 0.8510 - val_loss: 0.3574 - val_accuracy: 0.8527
# Epoch 87/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8498 - val_loss: 0.3563 - val_accuracy: 0.8533
# Epoch 88/100
# 188/188 [==============================] - 0s 3ms/step - loss: 0.3650 - accuracy: 0.8522 - val_loss: 0.3523 - val_accuracy: 0.8527
# Epoch 89/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8515 - val_loss: 0.3552 - val_accuracy: 0.8520
# Epoch 90/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3583 - accuracy: 0.8542 - val_loss: 0.3564 - val_accuracy: 0.8507
# Epoch 91/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8515 - val_loss: 0.3579 - val_accuracy: 0.8553
# Epoch 92/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8525 - val_loss: 0.3523 - val_accuracy: 0.8567
# Epoch 93/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8553 - val_loss: 0.3594 - val_accuracy: 0.8580
# Epoch 94/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8557 - val_loss: 0.3516 - val_accuracy: 0.8587
# Epoch 95/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3646 - accuracy: 0.8505 - val_loss: 0.3517 - val_accuracy: 0.8567
# Epoch 96/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.8517 - val_loss: 0.3480 - val_accuracy: 0.8493
# Epoch 97/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3624 - accuracy: 0.8562 - val_loss: 0.3489 - val_accuracy: 0.8580
# Epoch 98/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3581 - accuracy: 0.8572 - val_loss: 0.3523 - val_accuracy: 0.8593
# Epoch 99/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8545 - val_loss: 0.3533 - val_accuracy: 0.8607
# Epoch 100/100
# 188/188 [==============================] - 0s 2ms/step - loss: 0.3645 - accuracy: 0.8507 - val_loss: 0.3540 - val_accuracy: 0.8633

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training Loss')
sns.lineplot(epoch, val_loss, label = 'Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training accuracy')
sns.lineplot(epoch, val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes = True)
